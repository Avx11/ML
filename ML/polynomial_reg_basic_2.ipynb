# %%
import numpy as np
from matplotlib import pyplot as plt

from sklearn.linear_model import LinearRegression

from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import Ridge

# %%
X = 6* np.random.rand(100, 1) - 6
y = 0.3 * X**2 + X + 2 + np.random.randn(100, 1)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(X, y)

# %%
model = LinearRegression()
model.fit(X, y)
y_hat = model.predict(X)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(X, y)
ax.plot(X, y_hat)

# %%
X_poly = PolynomialFeatures(3).fit_transform(X)

# %%
X_poly.shape
# Out:
# (100, 4)

# %%
model2 = Ridge(alpha=0.003)
model2.fit(X_poly, y)
y_hat2 = model2.predict(X_poly)
X_b = np.linspace(X.min(), X.max(), 10).reshape(-1, 1)
X_b_poly = PolynomialFeatures(3).fit_transform(X_b)
y_b_hat = model2.predict(X_b_poly)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(X, y)
ax.plot(X_b, y_b_hat, color="red")
ax.set_ylabel("y")
ax.set_xlabel("X")
# Out:
# Text(0.5, 0, 'X')

# %% [markdown]
# # make_pipeline

# %%
from sklearn.pipeline import make_pipeline

# %%
pipeline = make_pipeline(PolynomialFeatures(10), 
                          LinearRegression())

# %%
pipeline.fit(X, y)
# Out:
# Pipeline(steps=[('polynomialfeatures', PolynomialFeatures(degree=10)),
#                 ('linearregression', LinearRegression())])

# %%
X_b = np.linspace(X.min(), X.max(), 100).reshape(-1, 1)

# %%
y_hat_b = pipeline.predict(X_b)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(X, y)
ax.plot(X_b, y_hat_b, color="red")
ax.set_ylabel("y")
ax.set_xlabel("X")
# Out:
# Text(0.5, 0, 'X')

# %%
pipeline = make_pipeline(PolynomialFeatures(20), 
                          LinearRegression())

# %%
pipeline.fit(X, y)
# Out:
# Pipeline(steps=[('polynomialfeatures', PolynomialFeatures(degree=20)),
#                 ('linearregression', LinearRegression())])

# %%
X_b = np.linspace(X.min(), X.max(), 100).reshape(-1, 1)

# %%
y_hat_b = pipeline.predict(X_b)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(X, y)
ax.plot(X_b, y_hat_b, color="red")
ax.set_ylabel("y")
ax.set_xlabel("X")
# Out:
# Text(0.5, 0, 'X')

# %%
pipeline = make_pipeline(PolynomialFeatures(30), 
                          LinearRegression())

# %%
pipeline.fit(X, y)
# Out:
# Pipeline(steps=[('polynomialfeatures', PolynomialFeatures(degree=30)),
#                 ('linearregression', LinearRegression())])

# %%
X_b = np.linspace(X.min(), X.max(), 100).reshape(-1, 1)

# %%
y_hat_b = pipeline.predict(X_b)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(X, y)
ax.plot(X_b, y_hat_b, color="red")
ax.set_ylabel("y")
ax.set_xlabel("X")
# Out:
# Text(0.5, 0, 'X')
